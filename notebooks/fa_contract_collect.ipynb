# %%
import pandas as pd
from pandas.errors import EmptyDataError

file_path = "../data/fa_contract_urls.csv"

try:
    urls = pd.read_csv(file_path)

    if urls.empty:
        print("fa_contract_urls.csv에 데이터가 없습니다.")
        print("형식 예시:")
        print("fa_year,player_name,url")
        print("2024,오지환,기사URL")
    else:
        display(urls)

except EmptyDataError:
    print("fa_contract_urls.csv 파일이 비어 있습니다.")
    print("VS Code에서 파일을 열고 첫 줄에 아래 헤더를 넣어주세요:")
    print("fa_year,player_name,url")
# Out:
# fa_contract_urls.csv에 데이터가 없습니다.
# 형식 예시:
# fa_year,player_name,url
# 2024,오지환,기사URL
